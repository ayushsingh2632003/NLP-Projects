# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsingh2632003/NLP-Projects/blob/main/amazon_review_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/NLP_UD/amazon review classification/amazon_cells_labelled.txt', sep='\t',header=None)

# %%
df
# Out:
#                                                      0  1
# 0    So there is no way for me to plug it in here i...  0
# 1                          Good case, Excellent value.  1
# 2                               Great for the jawbone.  1
# 3    Tied to charger for conversations lasting more...  0
# 4                                    The mic is great.  1
# ..                                                 ... ..
# 995  The screen does get smudged easily because it ...  0
# 996  What a piece of junk.. I lose more calls on th...  0
# 997                       Item Does Not Match Picture.  0
# 998  The only thing that disappoint me is the infra...  0
# 999  You can not answer calls with the unit, never ...  0
#
# [1000 rows x 2 columns]

# %%
print(df.columns)
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df[0]
# Out:
# 0      So there is no way for me to plug it in here i...
# 1                            Good case, Excellent value.
# 2                                 Great for the jawbone.
# 3      Tied to charger for conversations lasting more...
# 4                                      The mic is great.
#                              ...
# 995    The screen does get smudged easily because it ...
# 996    What a piece of junk.. I lose more calls on th...
# 997                         Item Does Not Match Picture.
# 998    The only thing that disappoint me is the infra...
# 999    You can not answer calls with the unit, never ...
# Name: 0, Length: 1000, dtype: object

# %%
df[1]
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: 1, Length: 1000, dtype: int64

# %%
df
# Out:
#                                                      0  1
# 0    So there is no way for me to plug it in here i...  0
# 1                          Good case, Excellent value.  1
# 2                               Great for the jawbone.  1
# 3    Tied to charger for conversations lasting more...  0
# 4                                    The mic is great.  1
# ..                                                 ... ..
# 995  The screen does get smudged easily because it ...  0
# 996  What a piece of junk.. I lose more calls on th...  0
# 997                       Item Does Not Match Picture.  0
# 998  The only thing that disappoint me is the infra...  0
# 999  You can not answer calls with the unit, never ...  0
#
# [1000 rows x 2 columns]

# %%
col_names=['reviews','sentiments']
df.columns=col_names

# %%
df
# Out:
#                                                reviews  sentiments
# 0    So there is no way for me to plug it in here i...           0
# 1                          Good case, Excellent value.           1
# 2                               Great for the jawbone.           1
# 3    Tied to charger for conversations lasting more...           0
# 4                                    The mic is great.           1
# ..                                                 ...         ...
# 995  The screen does get smudged easily because it ...           0
# 996  What a piece of junk.. I lose more calls on th...           0
# 997                       Item Does Not Match Picture.           0
# 998  The only thing that disappoint me is the infra...           0
# 999  You can not answer calls with the unit, never ...           0
#
# [1000 rows x 2 columns]

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.head()
# Out:
#                                              reviews  sentiments
# 0  So there is no way for me to plug it in here i...           0
# 1                        Good case, Excellent value.           1
# 2                             Great for the jawbone.           1
# 3  Tied to charger for conversations lasting more...           0
# 4                                  The mic is great.           1

# %%
df['sentiments'].value_counts()
# Out:
# 0    500
# 1    500
# Name: sentiments, dtype: int64

# %%
df.isnull().sum()
# Out:
# reviews       0
# sentiments    0
# dtype: int64

# %%
x=df['reviews']
y=df['sentiments']

# %%
df.shape
# Out:
# (1000, 2)

# %%
from gensim.models import Word2Vec

# %%
import nltk
nltk.download('stopwords')
import nltk

# Download the WordNet data
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# Download NLTK resources (if not done before)
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize

# Assuming your data is stored in a DataFrame named 'df'
# with columns 'reviews' and 'sentiments'
# Example: df = pd.read_csv('your_dataset.csv')

# Text Preprocessing
df['reviews'] = df['reviews'].apply(lambda x: x.lower())
df['reviews'] = df['reviews'].apply(lambda x: word_tokenize(x))

# %%
# Word2Vec model training
word2vec_model = Word2Vec(sentences=df['reviews'], vector_size=100, window=5, min_count=1, workers=4)

# %%
# Feature Extraction
def get_feature_vector(review):
    word_vectors = [word2vec_model.wv[word] for word in review if word in word2vec_model.wv]
    if not word_vectors:
        return None
    return sum(word_vectors) / len(word_vectors)

df['feature_vector'] = df['reviews'].apply(get_feature_vector)

# %%
# Remove rows with None feature vectors
df = df.dropna()

# Data Splitting
X_train, X_test, y_train, y_test = train_test_split(df['feature_vector'].tolist(), df['sentiments'], test_size=0.2, random_state=42)

# %%
len(df['feature_vector'].tolist())
# Out:
# 1000

# %%
df['sentiments']
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: sentiments, Length: 1000, dtype: int64

# %%
X_train
# Out:
# [array([-0.06898339,  0.11959233,  0.05137069,  0.0600677 ,  0.00272119,
#         -0.31721395,  0.09147559,  0.3793694 , -0.19517592, -0.18591726,
#          0.02390581, -0.24367252, -0.10963281,  0.09462298,  0.06865712,
#         -0.10068607,  0.08322519, -0.10875984, -0.0441364 , -0.38582397,
#          0.11548914,  0.04554038,  0.12341034, -0.09109236, -0.08915934,
#          0.03456844, -0.13373296, -0.06784072, -0.1202554 ,  0.0703365 ,
#          0.18887396,  0.01515364,  0.11330938, -0.19546951, -0.05166365,
#          0.24216929,  0.00840166, -0.1253083 , -0.04277904, -0.28836194,
#          0.06398238, -0.18741861, -0.02100494,  0.0164349 ,  0.18377759,
#         -0.06486859, -0.1652896 , -0.05969323,  0.10970211,  0.0913356 ,
#          0.08966598, -0.11163833, -0.0024487 , -0.02972807, -0.0991773 ,
#          0.10029304,  0.07334361, -0.01323482, -0.17082265,  0.04143173,
#         -0.01237261, -0.02556591,  0.02675149, -0.0175497 , -0.1826421 ,
# ...

# %%
df['sentiments']
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: sentiments, Length: 1000, dtype: int64

# %%
# SVM Model
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Prediction and Evaluation
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.535
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51        93
#            1       0.57      0.54      0.56       107
#
#     accuracy                           0.54       200
#    macro avg       0.53      0.53      0.53       200
# weighted avg       0.54      0.54      0.54       200

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize

# Assuming your data is stored in a DataFrame named 'df'
# with columns 'reviews' and 'sentiments'
# Example: df = pd.read_csv('your_dataset.csv')

# Convert the 'reviews' column to lowercase and tokenize each review
df['reviews'] = df['reviews'].apply(lambda review: ' '.join(review).lower())
df['reviews'] = df['reviews'].apply(lambda review: word_tokenize(review))

word2vec_model = Word2Vec(sentences=df['reviews'], vector_size=100, window=5, min_count=1, workers=4)

# Feature Extraction
def get_feature_vector(review):
    word_vectors = [word2vec_model.wv[word] for word in review if word in word2vec_model.wv]
    if not word_vectors:
        return None
    return sum(word_vectors) / len(word_vectors)

df['feature_vector'] = df['reviews'].apply(get_feature_vector)

# Remove rows with None feature vectors
df = df.dropna()

# Data Splitting
X_train, X_test, y_train, y_test = train_test_split(df['feature_vector'].tolist(), df['sentiments'], test_size=0.2, random_state=42)

# Hyperparameter Tuning using Grid Search
param_grid = {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf']}
grid_search = GridSearchCV(SVC(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

best_svm_model = grid_search.best_estimator_

# Evaluate the best model
y_pred_best = best_svm_model.predict(X_test)
accuracy_best = accuracy_score(y_test, y_pred_best)
report_best = classification_report(y_test, y_pred_best)

print(f'Best Model Accuracy: {accuracy_best}')
print(f'Best Model Classification Report:\n{report_best}')
# Out:
# Best Model Accuracy: 0.6
# Best Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.73      0.63        93
#            1       0.68      0.49      0.57       107
#
#     accuracy                           0.60       200
#    macro avg       0.61      0.61      0.60       200
# weighted avg       0.62      0.60      0.60       200

# %%
# Define a function for text preprocessing and feature extraction
def preprocess_and_extract_features(text):
    # Preprocess the input text
    text = ' '.join(word_tokenize(text.lower()))

    # Extract features using the trained Word2Vec model
    feature_vector = get_feature_vector(text)

    return feature_vector

# Example of a random text
random_text = "This product is amazing! I love it."

# Preprocess and extract features for the random text
random_text_features = preprocess_and_extract_features(random_text)

# Check sentiment using the trained SVM model
predicted_sentiment = best_svm_model.predict([random_text_features])[0]

# Map the predicted sentiment to "good" or "bad"
sentiment_label = "good" if predicted_sentiment == 1 else "bad"

# Print the result
print(f"Predicted Sentiment for the random text: {sentiment_label}")
# Out:
# Predicted Sentiment for the random text: bad
